# %%
# Установка необходимых библиотек
import sys
# !pip install pandas
# !pip install tqdm
# !pip install pysubs2
# Out:
# Requirement already satisfied: pandas in c:\users\yamilova_da\documents\anaconda\lib\site-packages (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\yamilova_da\documents\anaconda\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\yamilova_da\documents\anaconda\lib\site-packages (from pandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\yamilova_da\documents\anaconda\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\yamilova_da\documents\anaconda\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)
# Requirement already satisfied: tqdm in c:\users\yamilova_da\documents\anaconda\lib\site-packages (4.47.0)
# Requirement already satisfied: pysubs2 in c:\users\yamilova_da\documents\anaconda\lib\site-packages (0.2.4)

# %%
# импорт зависимостей
import re
from pathlib import Path
import pysubs2
import os
import pandas as pd
import IPython.display as ipd
from tqdm.notebook import tqdm
import csv
import fnmatch
import soundfile as sf
import numpy as np

# %%
class TextInspector:    
    def __init__(self, phrases, full_check=True):
        self.clone = {'a': 'а','c': 'с','e': 'е','o': 'о','p': 'р','x': 'х','y': 'у','A': 'А','B': 'В','C': 'С','E': 'Е','H': 'Н','K':'К','M': 'М','O': 'О','P': 'Р','T': 'Т','X': 'Х'}
        self.total_words = 0
        self.words_without_stress = []
        self.words_with_many_stress = []        
        self.phrases = phrases
        
        if full_check:
            self.check_strange_stress()
#             self.check_latin_symbols()
            self.check_numbers_symbols()
            self.check_last_phrase_symbol()
            
        
    def get_symbols(self):
        symbols_set = set()
        output_repr = ''
        
        for phrase in self.phrases:
            symbols_set.update(phrase)
            
        for i,symbol in enumerate(sorted(list(symbols_set))):
            if i%10==0:
                output_repr+='\n'
            
            output_repr += f" ({symbol} {ord(symbol)}) \t"
        
        print(output_repr)
                     
    def get_words_stat(self):
        for i,phrase in enumerate(self.phrases):
            for word in re.findall(r'([а-яёА-ЯЁ\'-]+)', phrase):
                stress_count = self.stress_count(word)
                if stress_count==0 and self.vowel_count(word)>1:
                    self.words_without_stress.append((i+1, word))
                elif stress_count>1:
                    self.words_with_many_stress.append((i+1, word))
                    
                self.total_words+=1
                
        print(f"Total words: {self.total_words}\nWords without stress: {len(self.words_without_stress), self.words_without_stress}\nWords with many stress: {len(self.words_with_many_stress), self.words_with_many_stress}", end='\n\n')
            
    def check_strange_stress(self):
        for i,phrase in enumerate(self.phrases):
            flag = False
            for index in self._accents_indices(phrase):
                if index == 0 or phrase[index-1] not in "уеыаоэяиюёУЕЫАОЭЯИЮЁ'":
                    flag = True
            
            if flag:
                print(f"Bad stress in {i+1} phrase : {phrase}")
    
    def check_numbers_symbols(self):
        for i,phrase in enumerate(self.phrases):
            result = re.findall(r'([0-9]+)', phrase)            
            if len(result)>0:
                print(f"Numbers symbols {result} in {i+1} phrase : {phrase}")
                
    def check_latin_symbols(self):
        for i,phrase in enumerate(self.phrases):
            result = re.findall(r'([a-zA-Z]+)', phrase)            
            if len(result)>0:
                print(f"Latin symbols {result} in {i+1} phrase : {phrase}")
                
    def check_last_phrase_symbol(self):
        indices = []
        for i,phrase in enumerate(self.phrases):
            if phrase != "":
                if phrase[-1] not in '.!?"':
                    indices.append(i+1)
            
        if len(indices)>0:
            print(f"Bad end of phrase in: {indices}")
            
    def _accents_indices(self,text):
        indices = []
        previous_len = 0
        i = text.find("'")

        while i>-1:
            indices.append(i+previous_len)
            previous_len += i+1
            i = text[previous_len:].find("'")

        return indices
        
    def put_stress_one_vowel_words(self):
         for i,phrase in enumerate(self.phrases):
            parts = phrase.split()
            for j,part in enumerate(parts):
                stress_count = self.stress_count(part)
                vowels = self.vowels(part)
                if len(vowels)==1 and stress_count==0:
                    parts[j] = part.replace(vowels, vowels+"'")
                    
            self.phrases[i] = ' '.join(parts).strip()

    def replace_separate_latins(self):
        for i,phrase in enumerate(self.phrases):
            parts = phrase.split()
            for j,part in enumerate(parts):
                latins = re.findall(r'([a-zA-Z]+)', part) 
                if len(latins)==1 and latins[0] in self.clone:
                    parts[j] = part.replace(latins[0], self.clone[latins[0]])
            
            self.phrases[i] = ' '.join(parts).strip()
            
    def replace(self, old_char, new_char):
        for i,phrase in enumerate(self.phrases):
            self.phrases[i] = phrase.replace(old_char, new_char)
            
    def show_abbr_and_latin(self):
        for i,phrase in enumerate(self.phrases):
            result = re.findall(r'([^\s]+\[+(?:[^\s])+\])', phrase)
            
            if len(result)>0:
                print(f"Abbr and latin disclosure in {i+1}: {result}")
            
    def find_phrase_with_str(self, string):
        return [(i+1, phrase) for i,phrase in enumerate(self.phrases) if string in phrase]
    
    def vowels(self, word):
        return re.sub(r'([^уеыаоэяиюёУЕЫАОЭЯИЮЁ]+)', "", word)
    
    def vowel_count(self, text):
        return len(self.vowels(text))
    
    def stress_count(self, text):
        return text.count("'")

# %% [raw]
# Класс для проверки текстовых корпусов
# Работает со списком строк, который передаётся в конструктор. По умолчанию включена полная проверка.

# %%
for ass_file in Path(r"C:\Users\yamilova_da\Desktop\Дроздов_Оля").glob("*.ass"):
    print(ass_file.stem)
    try:
        subs = pysubs2.load(ass_file)
    #     with open(ass_file, "r", encoding="utf-8") as subs:
    except AttributeError:
        print("0"+ass_file.stem)
        next
    phrases = [line.text for line in subs]
#         phrases = [line.replace('\n', '') for line in subs]

    test = TextInspector(phrases)
    
        # заменяем неугодные символы
    test.replace("…", "...")
    test.replace(chr(8230), "")
    test.replace(chr(171), '"')
    test.replace(chr(187), '"')
    test.replace(chr(8212),'-')
    test.replace(chr(8211),'-')
    
    test.words_without_stress
    test.replace_separate_latins()
#     test.put_stress_one_vowel_words()
    
    test.get_symbols()
    test.get_words_stat()
    test.words_without_stress
    for line,phrase in zip(subs,test.phrases):
        
        line.text = phrase

    subs.save(ass_file)
# Out:
# 2018_04_14_to_record_11_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (; 59) 	 (? 63)
#  (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081)
#  (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091)
#  (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101)
#  (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 7112
# Words without stress: (10, [(47, 'уши'), (103, 'уши'), (132, 'полу'), (317, 'руки'), (767, 'было'), (819, 'было'), (850, 'руки'), (1148, 'руку'), (1154, 'руку'), (1158, 'было')])
# Words with many stress: (8, [(75, "о'чень-о'чень"), (87, "никогда'-никогда'"), (90, "о'чень-о'чень"), (153, "до'чки-ма'тери"), (457, "та'к-та'к"), (499, "туда'-сюда'"), (1057, "до'чки-ма'тери"), (1061, "далеко'-далеко'")])
#
# 2018_04_19_to_record_12_master_1
# Bad end of phrase in: [255]
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (; 59) 	 (? 63) 	 (L 76) 	 ([ 91) 	 (] 93) 	 (a 97) 	 (c 99) 	 (d 100) 	 (e 101) 	 (h 104)
#  (l 108) 	 (o 111) 	 (r 114) 	 (t 116) 	 (v 118) 	 (w 119) 	 (А 1040) 	 (Г 1043) 	 (З 1047) 	 (О 1054)
#  (Р 1056) 	 (С 1057) 	 (Т 1058) 	 (У 1059) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077)
#  (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087)
#  (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097)
#  (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 2593
# Words without stress: (4, [(32, 'УАЗами'), (62, 'ГОСТе'), (156, 'было'), (205, 'было')])
# Words with many stress: (16, [(18, "а''нтирелигио'зную"), (27, "ква''сова'рни"), (32, "ма''лолитра'жка"), (32, "ремо''нтоприго'дна"), (76, "де'сять-двена'дцать"), (77, "то''лстоподо'швенные"), (98, "три'-четы'ре"), (100, "моло''чноки'слого"), (148, "и'мени-о'тчеству"), (171, "и'мени-о'тчеству"), (189, "моло''чноки'слое"), (217, "а'нгела-пу'тника"), (237, "петербу'ргско-варша'вской"), (242, "су''перпопуля'рным"), (247, "па''стеризо'ванный"), (254, "бле'дно-жё'лтые")])
#
# Review_05_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (; 59) 	 (? 63) 	 ([ 91) 	 (] 93) 	 (В 1042) 	 (Г 1043) 	 (Д 1044) 	 (Е 1045) 	 (З 1047) 	 (И 1048)
#  (Й 1049) 	 (К 1050) 	 (Л 1051) 	 (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056) 	 (С 1057) 	 (Т 1058)
#  (У 1059) 	 (Х 1061) 	 (Ч 1063) 	 (Э 1069) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077)
#  (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087)
#  (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097)
#  (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 2104
# Words without stress: (1, [(29, 'ДНК-бомбу')])
# Words with many stress: (29, [(3, "ки''новселе'нной"), (4, "мечта'тель-разгильдя'й"), (9, "ро'к-му'зыки"), (10, "пи'сарь-зау'чка"), (12, "и'нди-и'гры"), (18, "су''пергеро'я"), (20, "ки''новселе'нной"), (21, "давны'м-давно'"), (28, "челове'к-пау'к"), (45, "ло'с-а'нджелес"), (60, "ми''кроко'смос"), (65, "Стри''мфе'сте"), (85, "живо'тное-фамилья'р"), (86, "ки''нособы'тий"), (92, "ме''жмировы'х"), (97, "са''моповто'рами"), (106, "челове'к-мураве'й"), (108, "ге''ймдиза'йна"), (114, "би''оро'бота"), (114, "ни''троглицери'на"), (116, "ка''т-сце'ны"), (116, "ка''т-ка'дры"), (129, "пре'сс-материа'лов"), (130, "Стри''мфе'ста"), (139, "а'льфа-саме'ц"), (150, "Стри''мфе'сте"), (153, "фи'тнес-коспле'й"), (189, "ги''перфемини'стка"), (194, "су''пергеро'йский")])
#
# Review_06_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (? 63) 	 (C 67)
#  (D 68) 	 ([ 91) 	 (] 93) 	 (А 1040) 	 (В 1042) 	 (Н 1053) 	 (П 1055) 	 (С 1057) 	 (Т 1058) 	 (Э 1069)
#  (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081)
#  (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091)
#  (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102)
#  (я 1103) 	 (ё 1105)
# Total words: 754
# Words without stress: (0, [])
# Words with many stress: (3, [(8, "челове'ка-муравья'"), (48, "челове'ка-муравья'"), (64, "ки''ноблокба'стера")])
#
# Review_07_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (? 63) 	 ([ 91) 	 (] 93) 	 (b 98) 	 (e 101) 	 (i 105) 	 (m 109) 	 (o 111) 	 (v 118) 	 (А 1040)
#  (Б 1041) 	 (В 1042) 	 (Г 1043) 	 (Д 1044) 	 (Е 1045) 	 (З 1047) 	 (И 1048) 	 (Й 1049) 	 (Л 1051) 	 (М 1052)
#  (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056) 	 (С 1057) 	 (Т 1058) 	 (У 1059) 	 (Ф 1060) 	 (Ц 1062) 	 (Ч 1063)
#  (Ш 1064) 	 (Э 1069) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079)
#  (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089)
#  (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099)
#  (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 2218
# Words without stress: (0, [])
# Words with many stress: (20, [(12, "го'род-столи'ца"), (20, "кло'уна-при'нца"), (42, "ба'за-ха'б"), (46, "ге''ймдиза'йнера"), (56, "му''льтсериа'ле"), (63, "ви''деоигры'"), (70, "ге''ймдиза'йнер"), (72, "ви''деои'гр"), (78, "богатыре'й-пирря'н"), (79, "гни''локро'вием"), (87, "о''гневоло'сая"), (93, "све''рхпопуля'рные"), (95, "ба'с-ла'ге"), (105, "фо''тосе'та"), (145, "ги'к-соо'бщество"), (150, "ба'са-ла'га"), (155, "проду'кта-замени'теля"), (162, "ба'с-ла'г"), (179, "спе''цопера'ции"), (193, "серберна'р-уби'йца")])
#
# Review_08_master_1
# Numbers symbols ['2'] in 70 phrase : 2B[два' бэ'] сли'шком идеа'льна, что'бы бы'ть пра'вдой, поэ'тому объективи'руйте её' на' здоро'вье.
# Numbers symbols ['2'] in 130 phrase : плю'с повя'зка на' глаза'х, кото'рая де'лает 2b[два' бэ'] ещё' и' зага'дочной (ка'ждый ду'мает в ме'ру свое'й испо'рченности).
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (2 50)
#  (: 58) 	 (? 63) 	 ([ 91) 	 (] 93) 	 (b 98) 	 (А 1040) 	 (Б 1041) 	 (В 1042) 	 (Г 1043) 	 (Д 1044)
#  (Е 1045) 	 (Ж 1046) 	 (И 1048) 	 (Й 1049) 	 (К 1050) 	 (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056)
#  (С 1057) 	 (Т 1058) 	 (У 1059) 	 (Х 1061) 	 (Ц 1062) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076)
#  (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086)
#  (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096)
#  (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 2100
# Words without stress: (2, [(33, 'ИИ'), (53, 'было')])
# Words with many stress: (27, [(2, "ни'щие-упыри'"), (19, "ви''деоигры'"), (23, "ви''деои'гр"), (31, "де'вушку-пасха'нтера"), (32, "взры''воопа'сные"), (32, "терро'р-кни'ги"), (36, "го''ловоло'мкой"), (67, "ми''ллисеку'нды"), (73, "пти'цей-сте''нола'зом"), (75, "са''мовыраже'ния"), (84, "по''лдере'вни"), (109, "ре''йнева'не"), (118, "ка'сл-ро'к"), (120, "пра''возащи'тников"), (134, "ка'сл-ро'ке"), (140, "ви''деобло'геры"), (165, "геро'ев-брута'лов"), (166, "персона'ж-конце'пция"), (174, "ви''деоигры'"), (177, "ры''жеволо'сая"), (180, "ра''знообра'зию"), (183, "ги'к-культу'рой"), (183, "ви''деои'гры"), (185, "ви''деои'гр"), (189, "дитя'-Неожи'данность"), (196, "су''перзлоде'йской"), (199, "са''моуби'йственную")])
#
# Review_09_master_1
# Numbers symbols ['3'] in 133 phrase : да'же 3D[три' дэ'] в реа'льном ми'ре почти' не'т: я' до'лго в нача'ле сеа'нса крути'л очки', пыта'ясь поня'ть - а' чего' оно' всё' тако'е пло'ское?
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (3 51)
#  (: 58) 	 (? 63) 	 (D 68) 	 ([ 91) 	 (] 93) 	 (Б 1041) 	 (В 1042) 	 (Г 1043) 	 (Д 1044) 	 (Е 1045)
#  (Ж 1046) 	 (И 1048) 	 (К 1050) 	 (Л 1051) 	 (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056) 	 (С 1057)
#  (Т 1058) 	 (У 1059) 	 (Ф 1060) 	 (Х 1061) 	 (Ц 1062) 	 (Ч 1063) 	 (Ш 1064) 	 (Э 1069) 	 (а 1072) 	 (б 1073)
#  (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083)
#  (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093)
#  (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103)
#  (ё 1105)
# Total words: 2073
# Words without stress: (0, [])
# Words with many stress: (17, [(11, "те'нь-коро'ль"), (22, "ки''ноадапта'цию"), (23, "сто'п-ка'драми"), (25, "би''осфе'рой"), (28, "кру''пнокали'берных"), (42, "се'кс-маши'ну"), (59, "дельфи'н-шту'рман"), (70, "ба'с-га'лу"), (71, "ки''ноэкра'не"), (83, "ры'ба-анва'к"), (85, "то'лько-то'лько"), (89, "ви''деоча'т"), (94, "су''пергерои'нь"), (144, "са''ундтре'к"), (144, "ки''нематографи'ческий"), (175, "по''лша'га"), (189, "инопланетя'не-гала'кты")])
#
# Review_10_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (; 59) 	 (? 63) 	 ([ 91) 	 (] 93) 	 (А 1040) 	 (Б 1041) 	 (В 1042) 	 (Г 1043) 	 (Д 1044) 	 (Е 1045)
#  (Ж 1046) 	 (З 1047) 	 (И 1048) 	 (Й 1049) 	 (К 1050) 	 (Л 1051) 	 (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055)
#  (Р 1056) 	 (С 1057) 	 (Т 1058) 	 (У 1059) 	 (Ф 1060) 	 (Х 1061) 	 (Ц 1062) 	 (Ч 1063) 	 (Э 1069) 	 (Я 1071)
#  (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081)
#  (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091)
#  (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101)
#  (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 2198
# Words without stress: (0, [])
# Words with many stress: (25, [(4, "спе''цэффе'ктов"), (5, "ки''новселе'нную"), (10, "ка''рдиосоставля'ющая"), (15, "о''бщепри'нятый"), (18, "шести''деся'тые"), (18, "семи''деся'тые"), (29, "вы''шенапи'санное"), (45, "про'сто-на'просто"), (51, "по''стапока'липсис"), (65, "о''строконе'чный"), (73, "мно''гокно'почных"), (81, "про''мофотогра'фии"), (87, "го'ре-ведьмаку'"), (88, "Ло'с-А'нджелесе"), (92, "ки''новселе'нной"), (101, "Каэ'р-Мо'рхене"), (105, "спе''цэффе'ктов"), (108, "чу'ть-чу'ть"), (110, "борде''льмама'н"), (131, "пя'ть-де'сять"), (136, "Старичо'к-Лесовичо'к"), (147, "пя'ть-се'мь"), (180, "но'у-ха'у"), (180, "ки''берспо'рте"), (188, "пе''рвостепе'нных")])
#
# Review_11_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (? 63) 	 ([ 91) 	 (] 93) 	 (А 1040) 	 (Б 1041) 	 (В 1042) 	 (Г 1043) 	 (Д 1044) 	 (Е 1045) 	 (Ж 1046)
#  (З 1047) 	 (И 1048) 	 (Й 1049) 	 (К 1050) 	 (Л 1051) 	 (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056)
#  (С 1057) 	 (Т 1058) 	 (У 1059) 	 (Ф 1060) 	 (Х 1061) 	 (Ч 1063) 	 (Щ 1065) 	 (Э 1069) 	 (Я 1071) 	 (а 1072)
#  (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082)
#  (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092)
#  (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102)
#  (я 1103) 	 (ё 1105)
# Total words: 2122
# Words without stress: (1, [(69, 'было')])
# Words with many stress: (20, [(13, "ки''берспортсме'на"), (15, "туда'-сюда'"), (19, "пятью''десятью'"), (28, "Четырё''хкра'тный"), (28, "ки''нопре'мии"), (41, "ки''берспортсме'нами"), (54, "А'нны-Генрие'тты"), (84, "а''нтигеро'й"), (91, "со''циологи'ческое"), (91, "а''нтропологи'ческое"), (94, "ки''берспортсме'ны"), (97, "кро''вожа'дный"), (113, "по''лфи'льма"), (135, "Нью'-Йо'рке"), (143, "програ'ммы-тренажё'ры"), (155, "са''моидентифика'ции"), (159, "фо''тоисто'рия"), (183, "спе''цэффе'кты"), (187, "фра'нко-кана'дский"), (187, "ки''норежиссё'р")])
#
# Review_12_master_1
#
#  (  32) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (; 59)
#  (? 63) 	 (А 1040) 	 (Б 1041) 	 (В 1042) 	 (Г 1043) 	 (Д 1044) 	 (Е 1045) 	 (З 1047) 	 (И 1048) 	 (К 1050)
#  (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056) 	 (С 1057) 	 (Т 1058) 	 (У 1059) 	 (Ф 1060) 	 (Х 1061)
#  (Ч 1063) 	 (Э 1069) 	 (Я 1071) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078)
#  (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088)
#  (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ы 1099)
#  (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 361
# Words without stress: (0, [])
# Words with many stress: (5, [(9, "ки''берспо'рт"), (16, "игроко'в-люби'телей"), (23, "старика'-отше'льника"), (25, "ко''смоо'перу"), (33, "ки''берспортсме'нов")])
#
# Tender_1_00_master_1
# Numbers symbols ['27'] in 178 phrase : на' четы'ре дня' ра'ньше аппендици'т на' подло'дке удали'л вра'ч япо'нской субмари'ны "I-27[и' два'дцать се'мь]" в глуби'нах бенга'льского зали'ва.
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (2 50)
#  (7 55) 	 (: 58) 	 (; 59) 	 (? 63) 	 (I 73) 	 ([ 91) 	 (] 93) 	 (А 1040) 	 (Б 1041) 	 (В 1042)
#  (Г 1043) 	 (Д 1044) 	 (И 1048) 	 (К 1050) 	 (Л 1051) 	 (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056)
#  (С 1057) 	 (Т 1058) 	 (У 1059) 	 (Ф 1060) 	 (Ч 1063) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076)
#  (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086)
#  (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096)
#  (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1893
# Words without stress: (4, [(17, 'вузы'), (115, 'ГУФСИН'), (119, 'госдумы'), (190, 'руки')])
# Words with many stress: (12, [(13, "би''орезона'нс"), (16, "де''льтапла'не"), (35, "су''перма'ркета"), (89, "са'нкт-петербу'рг"), (98, "полу''торагодова'лым"), (104, "са''мочу'вствие"), (106, "ко''нтраргуме'нта"), (115, "бо'жья-во'ля"), (119, "го''с-ду'мы"), (183, "бо'лее-ме'нее"), (186, "а''нтипиа'р-кампа'ния"), (194, "са'нкт-петербу'рге")])
#
# Tender_1_01_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (? 63) 	 ([ 91) 	 (] 93) 	 (В 1042) 	 (И 1048) 	 (Л 1051) 	 (М 1052) 	 (О 1054) 	 (Р 1056) 	 (С 1057)
#  (Ф 1060) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080)
#  (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090)
#  (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100)
#  (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1928
# Words without stress: (5, [(29, 'минстрое'), (42, 'научпопа'), (66, 'пин-код'), (160, 'ФИО'), (185, 'было')])
# Words with many stress: (12, [(13, "па''ранорма'льным"), (29, "ми''н-стро'е"), (36, "кри''птовалю'ту"), (42, "нау''ч-по'па"), (55, "би''оинжене'ров"), (58, "па''ранорма'льным"), (85, "сне''гоубо'рочный"), (93, "вы''шеперечи'сленному"), (109, "су''льфамедизи'на"), (132, "каю'т-компа'ния"), (187, "а''удиофа'йлы"), (194, "фу''фломици'ны")])
#
# Tender_1_02_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (? 63) 	 ([ 91) 	 (] 93) 	 (А 1040) 	 (Б 1041) 	 (В 1042) 	 (Г 1043) 	 (Д 1044) 	 (И 1048) 	 (К 1050)
#  (М 1052) 	 (Н 1053) 	 (О 1054) 	 (П 1055) 	 (Р 1056) 	 (С 1057) 	 (Т 1058) 	 (У 1059) 	 (Ф 1060) 	 (Ч 1063)
#  (Ш 1064) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080)
#  (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090)
#  (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100)
#  (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1883
# Words without stress: (11, [(9, 'были'), (9, 'были'), (56, 'пин-кода'), (76, 'были'), (98, 'было'), (117, 'пин-код'), (131, 'ПАО'), (134, 'минздрав'), (140, 'УИК'), (167, 'ОАО'), (168, 'вциом')])
# Words with many stress: (12, [(13, "де'мон-души'тель"), (36, "э'кс-гра'ф"), (37, "све''рхъесте'ственное"), (52, "о''перациони'стки"), (85, "нау'чно-популя'рной"), (87, "па''ранорма'льного"), (107, "све''рхспосо'бностей"), (134, "ми''н-здра'в"), (137, "де'моном-души'телем"), (139, "э''гоцентри'чны"), (160, "Ка''линингра'де"), (186, "па''ранорма'льное")])
#
# Tender_1_03_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (? 63) 	 (L 76)
#  (R 82) 	 ([ 91) 	 (] 93) 	 (a 97) 	 (d 100) 	 (e 101) 	 (g 103) 	 (i 105) 	 (o 111) 	 (p 112)
#  (r 114) 	 (t 116) 	 (u 117) 	 (v 118) 	 (В 1042) 	 (М 1052) 	 (П 1055) 	 (Р 1056) 	 (С 1057) 	 (а 1072)
#  (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082)
#  (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092)
#  (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103)
#  (ё 1105)
# Total words: 621
# Words without stress: (4, [(10, 'старпома'), (11, 'минсельхоза'), (17, 'было'), (27, 'СМС-уведомление')])
# Words with many stress: (4, [(10, "ста''р-по'ма"), (11, "ми''н-се''ль-хо'за"), (23, "здра''воохране'ние"), (49, "о''бщечелове'ческие")])
#
# Tender_2_00_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (? 63) 	 (F 70)
#  (T 84) 	 ([ 91) 	 (] 93) 	 (a 97) 	 (c 99) 	 (e 101) 	 (i 105) 	 (l 108) 	 (m 109) 	 (n 110)
#  (s 115) 	 (Б 1041) 	 (К 1050) 	 (М 1052) 	 (П 1055) 	 (С 1057) 	 (Т 1058) 	 (а 1072) 	 (б 1073) 	 (в 1074)
#  (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084)
#  (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094)
#  (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 443
# Words without stress: (3, [(1, 'сизо'), (33, 'госдуму'), (40, 'БПС-Сбербанком')])
# Words with many stress: (2, [(29, "кри''птовалю'т"), (33, "го''с-ду'му")])
#
# tender_3_00_master_1
# Numbers symbols ['200'] in 81 phrase : я' скоростно'й по'езд "ЭР-200[э'р две'сти]".
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (0 48) 	 (2 50) 	 (: 58)
#  (? 63) 	 ([ 91) 	 (] 93) 	 (Р 1056) 	 (У 1059) 	 (Э 1069) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075)
#  (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085)
#  (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095)
#  (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1967
# Words without stress: (5, [(16, 'толку'), (26, 'было'), (61, 'ночи'), (177, 'райбольницы'), (182, 'полночь')])
# Words with many stress: (18, [(22, "со''лнцезащи'тные"), (33, "желе''знодоро'жной"), (57, "ра''знообра'зно"), (63, "по''луглухо'й"), (75, "желе''знодоро'жные"), (76, "желе''знодоро'жной"), (84, "желе''знодоро'жной"), (84, "си''льноплюсовы'х"), (108, "желе''знодоро'жном"), (112, "эле''ктропо'езда"), (115, "рыболо'в-ро'дственник"), (119, "ари'шкой-труси'шкой"), (160, "желе''знодоро'жному"), (177, "ра''й-больни'цы"), (179, "желе''знодоро'жном"), (180, "туду'т-туду'т"), (180, "туду'т-туду'т"), (187, "желе''знодоро'жный")])
#
# tender_3_01_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (? 63) 	 (В 1042) 	 (Г 1043) 	 (О 1054) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077)
#  (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087)
#  (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097)
#  (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1985
# Words without stress: (1, [(126, 'уху')])
# Words with many stress: (20, [(7, "слова'-парази'ты"), (12, "желе''знодоро'жное"), (17, "желе''знодоро'жной"), (30, "эле''ктропо'езде"), (44, "а''эропла'на"), (78, "а''виала'йнеру"), (88, "мно''гообеща'юще"), (93, "эле''ктропо'езде"), (96, "краса'вец-руби'льник"), (102, "эле''ктропо'езд"), (127, "звала'-звала'"), (131, "желе''знодоро'жная"), (149, "жё'лто-ка'фельные"), (157, "по''луглухо'й"), (166, "те''плово'за"), (177, "пи''роте'хнику"), (178, "эле''ктропо'езд"), (185, "жу'к-подле'ц"), (185, "кро'т-слепе'ц"), (189, "вре''мяпровожде'ния")])
#
# tender_3_02_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (? 63) 	 ([ 91)
#  (] 93) 	 (Д 1044) 	 (К 1050) 	 (Л 1051) 	 (М 1052) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076)
#  (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086)
#  (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096)
#  (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1834
# Words without stress: (1, [(116, 'лиаз')])
# Words with many stress: (24, [(18, "ари'шкой-труси'шкой"), (43, "ба'тюшки-свя'ты"), (65, "са''монаде'янный"), (65, "а''втолюби'тель"), (71, "по''лго'да"), (75, "са''моутверди'ться"), (81, "эле''ктропо'езд"), (87, "собра'тья-поезда'"), (88, "ле''сопоса'дках"), (100, "тё'мно-стальну'ю"), (101, "зелё'ные-зелё'ные"), (116, "тё'мно-зелё'ным"), (132, "трё''хла'пый"), (140, "желе''знодоро'жном"), (149, "скве''рносло'в"), (157, "стре'лка-помо'щница"), (158, "желе''знодоро'жном"), (160, "по''лчаса'"), (170, "са''моутвержде'нии"), (174, "желе''знодоро'жные"), (188, "са''мочу'вствии"), (188, "трё''хэта'жно"), (192, "то'лько-то'лько"), (200, "сни'зу-вве'рх")])
#
# tender_3_03_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081)
#  (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091)
#  (ф 1092) 	 (х 1093) 	 (ч 1095) 	 (ш 1096) 	 (ы 1099) 	 (ь 1100) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 64
# Words without stress: (0, [])
# Words with many stress: (0, [])
#
# tender_4_00_master_1
#
#  (  32) 	 (! 33) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (; 59) 	 (? 63) 	 (Д 1044)
#  (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081)
#  (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091)
#  (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (ю 1102) 	 (я 1103)
#  (ё 1105)
# Total words: 1416
# Words without stress: (0, [])
# Words with many stress: (7, [(52, "жё'ны-ве'дьмы"), (67, "гармо'нюшка-ма'тушка"), (67, "хле'бушка-ба'тюшки"), (118, "хле'б-со'ль"), (122, "е'ле-е'ле"), (132, "и'з-по'д"), (189, "хле'б-со'ль")])
#
# tender_4_01_master_1
#
#  (  32) 	 (! 33) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (; 59) 	 (Л 1051) 	 (а 1072)
#  (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082)
#  (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092)
#  (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102)
#  (я 1103) 	 (ё 1105)
# Total words: 1375
# Words without stress: (0, [])
# Words with many stress: (12, [(34, "по''лца'рства"), (34, "по''лконя'"), (57, "бе''лоли'чка"), (58, "хле'б-со'ль"), (67, "мо'лодо-зе'лено"), (101, "ба'тюшка-сентя'брь"), (151, "му'жем-жено'й"), (158, "бла''гообра'зен"), (193, "хле'б-со'ль"), (195, "жена'-подру'га"), (196, "хле''боро'дный"), (197, "хле'бом-со'лью")])
#
# tender_4_02_master_1
#
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (; 59) 	 (? 63)
#  (Д 1044) 	 (К 1050) 	 (М 1052) 	 (Н 1053) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077)
#  (ж 1078) 	 (з 1079) 	 (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087)
#  (р 1088) 	 (с 1089) 	 (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097)
#  (ъ 1098) 	 (ы 1099) 	 (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1419
# Words without stress: (0, [])
# Words with many stress: (2, [(134, "мо''кропого'дна"), (189, "а'вгуст-леноро'ст")])
#
# tender_4_03_master_1
#
#  (  32) 	 (! 33) 	 (' 39) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58) 	 (Б 1041) 	 (В 1042) 	 (Д 1044)
#  (Ж 1046) 	 (О 1054) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079)
#  (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089)
#  (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099)
#  (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)
# Total words: 1382
# Words without stress: (2, [(85, 'ноги'), (141, 'кого')])
# Words with many stress: (6, [(7, "а'вгуст-густа'рь"), (118, "обма'нщик-апре'ль"), (125, "лю'бо-до'рого"), (155, "ба'тюшка-овё'с"), (179, "хле'ба-со'ли"), (196, "хле'ба-со'ли")])

# %%
test.get_symbols() # посмотрим на все символы
# Out:
#  (  32) 	 (! 33) 	 (" 34) 	 (' 39) 	 (( 40) 	 () 41) 	 (, 44) 	 (- 45) 	 (. 46) 	 (: 58)
#  (? 63) 	 (E 69) 	 (F 70) 	 (N 78) 	 ([ 91) 	 (] 93) 	 (a 97) 	 (b 98) 	 (c 99) 	 (d 100)
#  (e 101) 	 (f 102) 	 (i 105) 	 (l 108) 	 (m 109) 	 (n 110) 	 (o 111) 	 (p 112) 	 (r 114) 	 (s 115)
#  (t 116) 	 (u 117) 	 (v 118) 	 (y 121) 	 (z 122) 	 (ü 252) 	 (А 1040) 	 (К 1050) 	 (М 1052) 	 (Н 1053)
#  (О 1054) 	 (Ф 1060) 	 (а 1072) 	 (б 1073) 	 (в 1074) 	 (г 1075) 	 (д 1076) 	 (е 1077) 	 (ж 1078) 	 (з 1079)
#  (и 1080) 	 (й 1081) 	 (к 1082) 	 (л 1083) 	 (м 1084) 	 (н 1085) 	 (о 1086) 	 (п 1087) 	 (р 1088) 	 (с 1089)
#  (т 1090) 	 (у 1091) 	 (ф 1092) 	 (х 1093) 	 (ц 1094) 	 (ч 1095) 	 (ш 1096) 	 (щ 1097) 	 (ъ 1098) 	 (ы 1099)
#  (ь 1100) 	 (э 1101) 	 (ю 1102) 	 (я 1103) 	 (ё 1105)

# %%
test.get_words_stat()
# Out:
# Total words: 4572
# Words without stress: (28, [(1, 'Минэнерго'), (25, 'генплан'), (31, 'Минтранса'), (33, 'Минкультуры'), (45, 'Роскачество'), (53, 'Роскачества'), (91, 'Лендоке'), (98, 'было'), (102, 'БИОС-'), (106, 'Ростуризма'), (127, 'Госдуме'), (150, 'было'), (154, 'жилтоварищество'), (190, 'ОАЭ'), (1, 'Минэнерго'), (25, 'генплан'), (31, 'Минтранса'), (33, 'Минкультуры'), (45, 'Роскачество'), (53, 'Роскачества'), (91, 'Лендоке'), (98, 'было'), (102, 'БИОС-'), (106, 'Ростуризма'), (127, 'Госдуме'), (150, 'было'), (154, 'жилтоварищество'), (190, 'ОАЭ')])
# Words with many stress: (140, [(1, "ми''н-эне'рго"), (9, "трё''хдне'вного"), (14, "ми''крорайо'не"), (16, "шести''деся'тые"), (18, "интерне'т-се'рвисов"), (23, "соверше''нноле'тним"), (25, "ге''н-пла'н"), (28, "Ша'рм-эль-Ше'йх"), (28, "а''виакомпа'нии"), (29, "зло''ка'чественных"), (29, "но''вообразова'ний"), (31, "ми''н-тра'нса"), (33, "ми''н-культу'ры"), (34, "вре''мяпровожде'ния"), (35, "ту''р-маршру'ты"), (36, "Го''сду'ма"), (37, "ки''нокри'тика"), (45, "ро''с-ка'чество"), (49, "го''спрогра'ммы"), (49, "Тури'стско-рекреацио'нный"), (53, "ро''с-ка'чества"), (53, "ма''ложи'рной"), (55, "Пересла'вль-Зале'сский"), (56, "Са'нкт-Петербу'рг"), (62, "трё''хсо'т"), (67, "Ро''ссельхо''знадзо'ра"), (67, "Са'нкт-Петербу'рг"), (70, "о''нкодиспансе'ре"), (72, "ху''д-руко'м"), (75, "ту''ропера'тор"), (77, "нау'чно-культу'рную"), (84, "но''рдви'нд"), (84, "э''йрла'йнс"), (85, "взаи''мосвя'зь"), (85, "фи''з-нагру'зками"), (87, "по''литехни'ческом"), (88, "Уфа'-Аре'ну"), (91, "ле''н-до'ке"), (92, "ра''знообра'зными"), (94, "ки''ноле'нт"), (99, "И''нтерфа'кс"), (102, "жи''знеобеспече'ния"), (103, "су''перлуну'"), (106, "ро''стури'зма"), (108, "си''нео'кую"), (111, "Ки''нофестива'ль"), (112, "со''цсетя'х"), (115, "пре'сс-слу'жба"), (116, "дву''хсо'т"), (116, "реко''рдсме'на"), (118, "санато'рно-куро'ртном"), (124, "загра''н-па'спорт"), (127, "го''с-ду'ме"), (133, "Га'ла-конце'рт"), (145, "програ'мма-дефиле'"), (148, "а''эропо'рту"), (149, "ки''нофестива'ле"), (154, "жи''л-това'рищество"), (159, "семи''ме'сячный"), (160, "ю''жноамерика'нской"), (162, "о''бщегородско'го"), (179, "дву''хсо'т"), (180, "ко'нкурсе-марафо'не"), (181, "пре'сс-конфере'нции"), (182, "пяти''десятичетырё''хле'тнему"), (187, "а''виабиле'ты"), (191, "Ула'н-Удэ'"), (195, "Четырё''хэта'жный"), (196, "пре'сс-слу'жба"), (198, "пре'сс-слу'жбе"), (1, "ми''н-эне'рго"), (9, "трё''хдне'вного"), (14, "ми''крорайо'не"), (16, "шести''деся'тые"), (18, "интерне'т-се'рвисов"), (23, "соверше''нноле'тним"), (25, "ге''н-пла'н"), (28, "Ша'рм-эль-Ше'йх"), (28, "а''виакомпа'нии"), (29, "зло''ка'чественных"), (29, "но''вообразова'ний"), (31, "ми''н-тра'нса"), (33, "ми''н-культу'ры"), (34, "вре''мяпровожде'ния"), (35, "ту''р-маршру'ты"), (36, "Го''сду'ма"), (37, "ки''нокри'тика"), (45, "ро''с-ка'чество"), (49, "го''спрогра'ммы"), (49, "Тури'стско-рекреацио'нный"), (53, "ро''с-ка'чества"), (53, "ма''ложи'рной"), (55, "Пересла'вль-Зале'сский"), (56, "Са'нкт-Петербу'рг"), (62, "трё''хсо'т"), (67, "Ро''ссельхо''знадзо'ра"), (67, "Са'нкт-Петербу'рг"), (70, "о''нкодиспансе'ре"), (72, "ху''д-руко'м"), (75, "ту''ропера'тор"), (77, "нау'чно-культу'рную"), (84, "но''рдви'нд"), (84, "э''йрла'йнс"), (85, "взаи''мосвя'зь"), (85, "фи''з-нагру'зками"), (87, "по''литехни'ческом"), (88, "Уфа'-Аре'ну"), (91, "ле''н-до'ке"), (92, "ра''знообра'зными"), (94, "ки''ноле'нт"), (99, "И''нтерфа'кс"), (102, "жи''знеобеспече'ния"), (103, "су''перлуну'"), (106, "ро''стури'зма"), (108, "си''нео'кую"), (111, "Ки''нофестива'ль"), (112, "со''цсетя'х"), (115, "пре'сс-слу'жба"), (116, "дву''хсо'т"), (116, "реко''рдсме'на"), (118, "санато'рно-куро'ртном"), (124, "загра''н-па'спорт"), (127, "го''с-ду'ме"), (133, "Га'ла-конце'рт"), (145, "програ'мма-дефиле'"), (148, "а''эропо'рту"), (149, "ки''нофестива'ле"), (154, "жи''л-това'рищество"), (159, "семи''ме'сячный"), (160, "ю''жноамерика'нской"), (162, "о''бщегородско'го"), (179, "дву''хсо'т"), (180, "ко'нкурсе-марафо'не"), (181, "пре'сс-конфере'нции"), (182, "пяти''десятичетырё''хле'тнему"), (187, "а''виабиле'ты"), (191, "Ула'н-Удэ'"), (195, "Четырё''хэта'жный"), (196, "пре'сс-слу'жба"), (198, "пре'сс-слу'жбе")])

# %%
test.words_without_stress # слова без ударений с указанием номеров предложений для удобства редактирования файлу источнике
# Out:
# [(20, 'госуслуги'),
#  (22, 'руку'),
#  (62, 'лже-МФО'),
#  (92, 'госуслуги'),
#  (139, 'бизнесинвест')]

# %%
test.check_numbers_symbols() # проверка на наличие цифр в корпусе

# %%
test.check_strange_stress() # проверка на некорректные ударения

# %%
test.show_abbr_and_latin()

# %%
test.replace_separate_latins() # заменем всевозможные варианты случайной латиницы

# %%
test.check_latin_symbols() # смотрим на латиницу в корпусе
# Out:
# Latin symbols ['industrial', 'Einst', 'rzende', 'Neubauten'] in 36 phrase : и' во'т они' постепе'нно вхо'дят в ри'тм и' начина'ют оття'гиваться в по'лный ро'ст, получа'ется тако'й industrial[инда'стриал], ти'па Einstürzende[айшту'нценде] Neubauten[нойба'утэн].
# Latin symbols ['Fraud', 'prevention', 'service'] in 137 phrase : мы' испо'льзуем Fraud[фро'д] prevention[прывэ'ншн] service[сё'рвич] бюро' креди'тных исто'рий эквифа'кс.
# Latin symbols ['money', 'funny'] in 154 phrase : "в "money[ма'ни] funny[фа'нни]" тако'й спи'сок ведё'тся", - добавля'ет шу'стов.

# %%
test.put_stress_one_vowel_words() # ударение одногласных слов

# %% [raw]
# После всех манипуляций сохраняем в нужном файле.

# %% [raw]
# # если текст в формате *.ass
#
# target_path = Path()
# subs = pysubs2.load(target_path)
# phrases = [line.text for line in subs]
#
# test = TextInspector(test_ex, full_check=False)
# ...
#
# for line,phrase in zip(subs,test.phrases):
#     line.text = phrase
#
# subs.save(target_path)

# %% [raw]
# # если текст в формате *.txt
#
# target_path = Path(r)
# phrases = target_path.read_text(encoding='utf-8').split('\n')
#
# test = TextInspector(test_ex, full_check=False)
# ...
#
# target_path.write_text('\n'.join(test.phrases), encoding='utf-8')

# %% [markdown]
# Код ниже позволяет найти текстовые дубликаты в корпусах

# %%
# Вспомогательные функции

def find_all_files(path, expansion='.ass'):
    lst = []
    for root, dirnames, filenames in os.walk(path, followlinks=True):
        for filename in fnmatch.filter(filenames, '*' + expansion):
            lst.append(os.path.join(root, filename))
    return lst

def find_text_duplicates(speaker_path, output_path=None):
    ass = find_all_files(speaker_path, '.ass')
    all_dialogues = []

    for idx, file_ass in enumerate(tqdm(ass, desc='parse ass files')):
        subs = pysubs2.load(file_ass)
        audio_name = subs.aegisub_project['Audio File']
        ass_file = Path(file_ass).relative_to(speaker_path)

        for pos, line in enumerate(subs):
            if line.type == "Dialogue":
                start = pysubs2.substation.ms_to_timestamp(line.start)
                end = pysubs2.substation.ms_to_timestamp(line.end)
                all_dialogues.append((ass_file, audio_name, pos, line.plaintext, start, end))

    df = pd.DataFrame.from_records(all_dialogues, columns=['ass_file', 'audio_file', 'pos', 'text', 'start', 'end'])
    df['text_len'] = df['text'].str.len()

    # find text duplicates
    texts = df['text'].apply(lambda x: x.lower())
    duplicates_df = df[texts.isin(texts[texts.duplicated()])]
    duplicates_df = duplicates_df.sort_values(by=['text_len', 'text'])
    duplicates_df = duplicates_df.reset_index()
    duplicates_df = duplicates_df.drop(columns=['index','text_len'])
    print(f'found {duplicates_df.shape[0]} text duplicates.')

    # save table
    if output_path and duplicates_df.shape[0] > 0:
        save_path = output_path.joinpath(f'{speaker_path.name}_text_duplicates.tsv')
        duplicates_df.to_csv(save_path, sep='\t', index=True, quoting=csv.QUOTE_NONE)
        print('⚠ saved to:', save_path)

    return duplicates_df

def time_to_float(time):
    (h, m, s) = time.split(':')
    return np.float(h) * 3600 + np.float(m) * 60 + np.float(s)

def get_audio_by_idx(df, idx):
    row = df.loc[idx]
    ass_file = speaker_path.joinpath(row.ass_file)
    audio_file = ass_file.parent.joinpath(row.audio_file)
    start = time_to_float(row.start)
    end = time_to_float(row.end)
    audio, sr = sf.read(audio_file)
    audio = audio[int(start*sr): int(end*sr)]
    return audio, sr

# %%
# путь к корпусам диктора с ass файлами
speaker_path = Path(r'C:\Users\yamilova_da\Desktop\копирование\Дроздов_10')
# путь для сохраенения таблицы с дубликатами
output_path = Path(r'C:\Users\yamilova_da\Desktop')
# ищем дубликаты
# dupl_df = find_text_duplicates(speaker_path, output_path)
dupl_df = find_text_duplicates(speaker_path)

pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', 1000)
# кол-во столбцов для отображения
pd.set_option('display.max_columns', None)
# кол-во строк для отображения, выставляем None, чтобы выключить ограничение
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_rows', 20)

# отобразить датафрейм
display(dupl_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='parse ass files', max=25.0, style=ProgressStyle(descripti…
# found 25 text duplicates.
#                      ass_file                 audio_file  pos                                              text       start         end
# 0   tender_10_00_master_1.ass  tender_10_00_master_1.wav   16                                иди' к на'м жи'ть!  0:01:39.87  0:01:40.75
# 1   tender_10_01_master_1.ass  tender_10_01_master_1.wav  102                                иди' к на'м жи'ть!  0:08:27.16  0:08:28.00
# 2   tender_10_01_master_1.ass  tender_10_01_master_1.wav   36                               я' мы'шка-нору'шка.  0:02:55.79  0:02:56.98
# 3   tender_10_02_master_1.ass  tender_10_02_master_1.wav  104                               я' мы'шка-нору'шка.  0:08:57.25  0:08:58.57
# 4   tender_10_03_master_1.ass  tender_10_03_master_1.wav  182                               я' мы'шка-нору'шка.  0:15:35.32  0:15:36.65
# 5   tender_10_00_master_1.ass  tender_10_00_master_1.wav  165                             колесо' заверте'лось.  0:14:04.64  0:14:05.75
# 6   tender_10_02_master_1.ass  tender_10_02_master_1.wav   40                             колесо' заверте'лось.  0:03:32.50  0:03:33.66
# 7   tender_10_01_master_1.ass  tender_10_01_master_1.wav  149                            кто' в те'реме живё'т?  0:12:10.77  0:12:11.91
# 8   tender_10_03_master_1.ass  tender_10_03_master_1.wav  160                            кто' в те'реме живё'т?  0:13:40.69  0:13:41.75
# 9   tender_10_00_master_1.ass  tender_10_00_master_1.wav  122                            я' лягу'шка-кваку'шка.  0:10:26.49  0:10:27.78
# 10  tender_10_01_master_1.ass  tender_10_01_master_1.wav   37                            я' лягу'шка-кваку'шка.  0:02:58.41  0:02:59.79
# 11   tender_4_09_master_1.ass   tender_4_09_master_1.wav   76                  в зи'мний хо'лод вся'кий мо'лод.  0:05:32.45  0:05:34.16
# 12   tender_4_11_master_1.ass   tender_4_11_master_1.wav   43                  в зи'мний хо'лод вся'кий мо'лод.  0:03:11.40  0:03:13.13
# 13   tender_7_01_master_1.ass   tender_7_01_master_1.wav  186               нало'г на' доба'вленную сто'имость.  0:17:57.18  0:17:58.86
# 14   tender_7_03_master_1.ass   tender_7_03_master_1.wav   58               нало'г на' доба'вленную сто'имость.  0:05:17.12  0:05:18.85
# 15   tender_7_01_master_1.ass   tender_7_01_master_1.wav  140              "заче'м?" - хочу' я' отве'тить ему'.  0:13:39.47  0:13:41.20
# 16   tender_7_02_master_1.ass   tender_7_02_master_1.wav  148              "заче'м?" - хочу' я' отве'тить ему'.  0:14:31.80  0:14:33.58
# 17   Tender_6_00_master_1.ass   Tender_6_00_master_1.wav  185           и' зна'ете, на' свету' намно'го лу'чше.  0:19:12.48  0:19:14.48
# 18   Tender_6_01_master_1.ass   Tender_6_01_master_1.wav    2           и' зна'ете, на' свету' намно'го лу'чше.  0:00:18.59  0:00:20.73
# 19   tender_4_07_master_1.ass   tender_4_07_master_1.wav  148          зерно' в колоске' - не' спи' в холодке'.  0:10:00.88  0:10:03.16
# 20   tender_4_13_master_1.ass   tender_4_13_master_1.wav  116          зерно' в колоске' - не' спи' в холодке'.  0:08:27.73  0:08:29.92
# 21   tender_4_10_master_1.ass   tender_4_10_master_1.wav  138    семья' бе'з дете'й, что' цвето'к бе'з за'паха.  0:09:54.61  0:09:56.90
# 22   tender_4_11_master_1.ass   tender_4_11_master_1.wav  183    семья' бе'з дете'й, что' цвето'к бе'з за'паха.  0:13:26.25  0:13:28.63
# 23   Tender_6_00_master_1.ass   Tender_6_00_master_1.wav   85  и' никаки'х ночны'х препира'тельств с со'вестью.  0:08:56.77  0:08:59.34
# 24   Tender_6_01_master_1.ass   Tender_6_01_master_1.wav   53  и' никаки'х ночны'х препира'тельств с со'вестью.  0:05:07.12  0:05:09.57

# %%
# индексы из датафрейма
indexes = [21,22,23,24]
for idx in indexes:
    audio, sr = get_audio_by_idx(dupl_df, idx)
    print(idx, dupl_df.iloc[idx].text)
    ipd.display(ipd.Audio(audio, rate=sr))
# Out:
# 21 семья' бе'з дете'й, что' цвето'к бе'з за'паха.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 22 семья' бе'з дете'й, что' цвето'к бе'з за'паха.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 23 и' никаки'х ночны'х препира'тельств с со'вестью.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 24 и' никаки'х ночны'х препира'тельств с со'вестью.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# указываем индексы строк из датафрейма, которые необходимо закомментировать 
indexes_to_comment = [22,24]

for idx in indexes_to_comment:
    row = dupl_df.iloc[idx]
    ass_file = speaker_path.joinpath(row.ass_file)
    subs = pysubs2.load(ass_file)
    subs[row.pos].type = 'Comment'
    subs.save(ass_file)
    print(f'Файл {ass_file.relative_to(speaker_path)} обновлён.')
# Out:
# Файл tender_4_11_master_1.ass обновлён.
# Файл Tender_6_01_master_1.ass обновлён.

# %%
# указываем индексы строк из датафрейма, которые необходимо раcкомментировать 
indexes_to_uncomment = [365]

for idx in indexes_to_uncomment:
    row = dupl_df.iloc[idx]
    ass_file = speaker_path.joinpath(row.ass_file)
    subs = pysubs2.load(ass_file)
    subs[row.pos].type = 'Dialogue'
    subs.save(ass_file)
    print(f'Файл {ass_file.relative_to(speaker_path)} обновлён.')
# Out:
# Файл short_set_3_master_1.ass обновлён.
